# %% [markdown]
# ## More on Analyzing Constitutions
#
# In the previous workbook, we didn't get very far with our analysis. A reason for this is that we did not attempt to break down the constitutions very seriously. They have a definite structure, so we should take that into account and see where it gets us. Accordingly:

# %%
import os

import numpy as np
import pandas as pd

# %% [markdown]
# We select a file randomly, just to look at its structure. So:

# %%
filelist = os.listdir()
file     = filelist[16]
print(file)
# Out:
# AR1864_final_parts_0.txt

# %% [markdown]
# Let's read in the file line by line and make a list out of the non-blank components of the list.

# %%
with open(file) as f:
    content = f.readlines()
    
content = [x.strip() for x in content]
content = list(filter(None, content))

# %%
len(content)
# Out:
# 983

# %% [markdown]
# We see that we have these definitive markers for the beginning and end of certain things. So, ASTART marks the beginning of an article, and AEND marks the end of an article. We also can add in beginnings and endings for Sections. Anyways:

# %%
artbeg = np.zeros(len(content))
artend = np.zeros(len(content))

secbeg = np.zeros(len(content))
secend = np.zeros(len(content))

conbeg = np.zeros(len(content))
conend = np.zeros(len(content))

count = 0

for line in content:
    if line.find("CSTART") > 0:
        conbeg[count] = 1
    if line.find("CEND")   > 0:
        conend[count] = 1
    if line.find("ASTART") > 0:
        artbeg[count] = 1
    if line.find("AEND")   > 0:
        artend[count] = 1
    if line.find("SSTART") > 0:
        secbeg[count] = 1
    if line.find("SEND")   > 0:
        secend[count] = 1
    count = count + 1

# %% [markdown]
# So, we now can make a dataframe out of the constitution, for one:

# %%
Foo = pd.DataFrame([content, list(artbeg), list(artend), list(secbeg), list(secend), list(conbeg), list(conend)])

# %%
Foo = Foo.T

# %%
text_lines=np.zeros(len(content))
count = 0
for line in Foo[0]:
    if any(c for c in line if c.islower()):
        text_lines[count] = 1
    count = count + 1

# %%
TL = pd.DataFrame(text_lines)

# %%
Foo['textdum'] = TL

# %%
paragraphs = []
count = 0
for line in Foo[0]:
    newline = []
    if Foo['textdum'][count] == 1:
        newline.append(Foo['textdum'][count])
        
    count = count + 1

# %%
Foo
# Out:
#                                                      0  1  2  3  4  5  6  \
# 0                   Arkansas was done by Doug Campbell  0  0  0  0  0  0
# 1                                   It is ready to go.  0  0  0  0  0  0
# 2                                        JW 04/05/2005  0  0  0  0  0  0
# 3              *** CSTART AR 03/04/1864 02/11/1868 ***  0  0  0  0  1  0
# 4                        *** ASTART 9001.0 AR 1864 ***  1  0  0  0  0  0
# 5                        CONSTITUTION OF ARKANSAS-1864  0  0  0  0  0  0
# 6    We, the people of the State of Arkansas, havin...  0  0  0  0  0  0
# 7    in conformity with the Constitution of the Uni...  0  0  0  0  0  0
# 8    consequences of the existing rebellion, do her...  0  0  0  0  0  0
# 9    of the State of Arkansas, which assembled in t...  0  0  0  0  0  0
# 10   one thousand eight hundred and sixty-one, was,...  0  0  0  0  0  0
# 11    has been binding and obligatory upon the people.  0  0  0  0  0  0
# 12   That all the action of the State of Arkansas u...  0  0  0  0  0  0
# 13   ordinances, or of its constitution, whether le...  0  0  0  0  0  0
# 14   hereinafter provided,) was, and is hereby decl...  0  0  0  0  0  0
# 15   shall not be so construed as to affect the rig...  0  0  0  0  0  0
# 16   county seats, or to make invalid the acts of j...  0  0  0  0  0  0
# 17   authority to administer oaths, or take and cer...  0  0  0  0  0  0
# 18   other instruments of writing, or in the solemn...  0  0  0  0  0  0
# 19   debt or liability of the State of Arkansas inc...  0  0  0  0  0  0
# 20   legislature or any department of the governmen...  0  0  0  0  0  0
# 21                           recognized as obligatory.  0  0  0  0  0  0
# 22   And we, the people of the State of Arkansas, i...  0  0  0  0  0  0
# 23   loyal to the Government of the United States-t...  0  0  0  0  0  0
# 24   protection and blessings of the Federal Consti...  0  0  0  0  0  0
# 25   and the free pursuit of happiness, do agree to...  0  0  0  0  0  0
# 26   by the name and style of "the State of Arkansa...  0  0  0  0  0  0
# 27            Constitution for the government thereof:  0  0  0  0  0  0
# 28                                        *** AEND ***  0  1  0  0  0  0
# 29                        *** ASTART 001.0 AR 1864 ***  1  0  0  0  0  0
# ..                                                 ... .. .. .. .. .. ..
# 953                                          officers.  0  0  0  0  0  0
# 954                                       *** SEND ***  0  0  0  1  0  0
# 955              *** SSTART 006.0 9003.0 0 AR 1864 ***  0  0  1  0  0  0
# 956  SEC. 6. It is also further ordained and declar...  0  0  0  0  0  0
# 957  are not held on the said second Monday of Marc...  0  0  0  0  0  0
# 958  local officers provided for in the constitutio...  0  0  0  0  0  0
# 959  same manner as hereinbefore described, at any ...  0  0  0  0  0  0
# 960                         organized and represented.  0  0  0  0  0  0
# 961                                       *** SEND ***  0  0  0  1  0  0
# 962              *** SSTART 007.0 9003.0 0 AR 1864 ***  0  0  1  0  0  0
# 963  SEC. 7. The officers to be voted for in this e...  0  0  0  0  0  0
# 964  of state, auditor, treasurer, attorney-general...  0  0  0  0  0  0
# 965  and nine district attorneys (according to act ...  0  0  0  0  0  0
# 966  sixty-one,) county judges, clerks, sheriffs, c...  0  0  0  0  0  0
# 967  other officers provided for in the constitutio...  0  0  0  0  0  0
# 968  exist by law, and members of the legislature, ...  0  0  0  0  0  0
# 969  districts in force in the year one thousand ei...  0  0  0  0  0  0
# 970  districts Nos. 1 and 2, according to the Act a...  0  0  0  0  0  0
# 971  hundred and sixty-one, (no election being orde...  0  0  0  0  0  0
# 972  the election of Colonel James Johnson as the r...  0  0  0  0  0  0
# 973  hereby declared that all laws in force in this...  0  0  0  0  0  0
# 974  hundred and sixty-one, are still in force, not...  0  0  0  0  0  0
# 975  and which have not expired by limitation there...  0  0  0  0  0  0
# 976                                       *** SEND ***  0  0  0  1  0  0
# 977                                       *** AEND ***  0  1  0  0  0  0
# 978                             John McCoy, President.  0  0  0  0  0  0
# 979                                            Attest:  0  0  0  0  0  0
# 980                     ROBERT J. T. WHITE, Secretary.  0  0  0  0  0  0
# 981                   JAMES R. BERRY, Ass't Secretary.  0  0  0  0  0  0
# 982                                       *** CEND ***  0  0  0  0  0  1
#
#      textdum
# 0        1.0
# 1        1.0
# 2        0.0
# 3        0.0
# 4        0.0
# 5        0.0
# 6        1.0
# 7        1.0
# 8        1.0
# 9        1.0
# 10       1.0
# 11       1.0
# 12       1.0
# 13       1.0
# 14       1.0
# 15       1.0
# 16       1.0
# 17       1.0
# 18       1.0
# 19       1.0
# 20       1.0
# 21       1.0
# 22       1.0
# 23       1.0
# 24       1.0
# 25       1.0
# 26       1.0
# 27       1.0
# 28       0.0
# 29       0.0
# ..       ...
# 953      1.0
# 954      0.0
# 955      0.0
# 956      1.0
# 957      1.0
# 958      1.0
# 959      1.0
# 960      1.0
# 961      0.0
# 962      0.0
# 963      1.0
# 964      1.0
# 965      1.0
# 966      1.0
# 967      1.0
# 968      1.0
# 969      1.0
# 970      1.0
# 971      1.0
# 972      1.0
# 973      1.0
# 974      1.0
# 975      1.0
# 976      0.0
# 977      0.0
# 978      1.0
# 979      1.0
# 980      1.0
# 981      1.0
# 982      0.0
#
# [983 rows x 8 columns]
